# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# Ustawienie stylu seaborn
sns.set(style="whitegrid")

# Generowanie dwóch nienormalnych rozkładów
np.random.seed(0)
sample1 = np.random.exponential(scale=2, size=1000)
sample2 = np.random.chisquare(df=2, size=1000)+2

# Pierwszy subplot - histogramy
plt.figure(figsize=(8, 6))
sns.histplot(sample1, stat='density', cumulative=False, color=my_blue, label='$f(u)$', edgecolor='black', alpha=1)
sns.histplot(sample2, stat='density', cumulative=False, color=my_red, label='$g(u)$', edgecolor='black', alpha=0.9)
plt.legend(fontsize=16)
# plt.title('Histogramy')
plt.xlabel('u', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)
plt.ylabel('Prawdopodobieństwo', fontsize=16)
plt.xlim(0, 15)  # Ograniczenie osi x
plt.tight_layout()
plt.savefig('images2/histogramy_przyklad.png')

# Drugi subplot - skumulowane histogramy
plt.figure(figsize=(8, 6))
sns.histplot(sample1, stat='density', cumulative=True, color=my_blue, label='$F(u)$', edgecolor='black', alpha=1)
sns.histplot(sample2, stat='density', cumulative=True, color=my_red, label='$G(u)$', edgecolor='black',alpha=0.9)
plt.legend(fontsize=16)
# plt.title('Skumulowane histogramy')
plt.xlabel('u', fontsize=16)
plt.yticks(fontsize=16)
plt.xticks(fontsize=16)
plt.ylabel('Prawdopodobieństwo skumulowane', fontsize=16)
plt.xlim(0, 15)  # Ograniczenie osi x
plt.tight_layout()
plt.savefig('images2/histogramy_skumulowane.png')

# Wyświetlenie wykresów
plt.show()
